# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/
# Out:
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj

# %%
import os, json
names = os.listdir('/content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR-filtered (1)')
for name in names:
  json_file = os.path.join('/content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR-filtered (1)', name, name + '.json')
  with open(json_file, 'r') as json_file:
    report = json.load(json_file)
  print(name)
  print('FINDINGS:',report['FINDINGS'])
  print('INDICATION:',report['INDICATION'])
  print('\n')
# Out:
# s50414267
# FINDINGS: There is no focal consolidation, pleural effusion or pneumothorax.  Bilateral
#  nodular opacities that most likely represent nipple shadows. The
#  cardiomediastinal silhouette is normal.  Clips project over the left lung,
#  potentially within the breast. The imaged upper abdomen is unremarkable.
#  Chronic deformity of the posterior left sixth and seventh ribs are noted.
# INDICATION: ___F with new onset ascites  // eval for infection
#
#
# s53189527
# FINDINGS: The cardiac, mediastinal and hilar contours are normal. Pulmonary vasculature
#  is normal.  Lungs are clear. No pleural effusion or pneumothorax is present.
#  Multiple clips are again seen projecting over the left breast.  Remote
#  left-sided rib fractures are also re- demonstrated.
# INDICATION: ___F with shortness of breath
#
#
# s53911762
# FINDINGS: Single frontal view of the chest provided.
#
#  There is no focal consolidation, effusion, or pneumothorax. The
#  cardiomediastinal silhouette is normal.  Again seen are multiple clips
#  projecting over the left breast and remote left-sided rib fractures.  No free
#  air below the right hemidiaphragm is seen.
# INDICATION: ___F with cough  // acute process?
#
#
# s56699142
# FINDINGS: The lungs are clear of focal consolidation, pleural effusion or pneumothorax.
#  The heart size is normal.  The mediastinal contours are normal. Multiple
#  surgical clips project over the left breast, and old left rib fractures are
#  noted.
# INDICATION: ___ year old woman with cirrhosis.
#
#
# s57375967
# FINDINGS: PA and lateral views of the chest provided.   The lungs are adequately
#  aerated.
#
#  There is a focal consolidation at the left lung base adjacent to the lateral
#  hemidiaphragm. There is mild vascular engorgement. There is bilateral apical
#  pleural thickening.
#
#  The cardiomediastinal silhouette is remarkable for aortic arch calcifications.
#  The heart is top normal in size.
# INDICATION: ___M with hypoxia  // ?pna, aspiration.
#
#
# s51029426
# FINDINGS: No focal consolidation is seen.  There is no pleural effusion or pneumothorax.
#  The cardiac and mediastinal silhouettes are unremarkable.
# INDICATION: ___F with fever, hypotension  // r/o pneumonia
#
#
# s50336039
# FINDINGS: Again seen is the indwelling right-sided catheter, with tip over distal SVC.
#  In addition, there is a new right-sided PICC line, with tip overlying the
#  right atrium.  No pneumothorax detected.
#
#  Inspiratory volumes are low and the right hemidiaphragm remains elevated, with
#  opacity at the right base, similar to prior.  Minimal patchy opacity in the
#  retrocardiac region is improved slightly.  No gross effusion is detected on
#  this AP view.  No definite change in the cardiomediastinal silhouette.
#
#  Focal opacity the left upper zone represent artifact due to overlap of the
#  first anterior and fifth posterior left ribs.
# INDICATION: ___ year old woman with CNS lymphoma,  // assess for pleural
#  effusion prior to giving methotrexate
#
#
# s51967845
# FINDINGS: Right Port-A-Cath in place.  Elevated right hemidiaphragm, stable.  Bibasilar
#  opacities, mildly more prominent on the right, likely atelectasis.
#  Pneumonitis cannot be excluded in the appropriate clinical setting.  There may
#  be tiny right pleural effusion
# INDICATION: ___ year old woman with CNS lymphoma and AMS. Now with new fever.
#  // Eval fever
#
#
# s54898709
# FINDINGS: Mild cardiomegaly vascular congestion is improved when compared to ___
#  study.  Low lung volumes with stable bibasilar atelectasis are stable.  A
#  small left pleural effusion is stable.
# INDICATION: ___ year old woman with s4 dlbcl, tachypnea, now wheezing  //
#  aspiration
#
#
# s58117097
# FINDINGS: PA and lateral views of the chest provided.   Right chest wall Port-A-Cath is
#  noted with catheter tip in the region of the SVC.  There is marked elevation
#  of the right hemidiaphragm.  Lungs appear clear.  There is no focal
#  consolidation, effusion, or pneumothorax. The cardiomediastinal silhouette is
#  normal. Imaged osseous structures are intact.  No free air below the right
#  hemidiaphragm is seen.
# INDICATION: ___F with lymphoma, in for infectious workup and
#  escalation of therapy  // shortness of breath
#
#
# s55199984
# FINDINGS: The lungs are symmetrically inflated and clear. No pleural effusion,
#  pneumothorax, or pneumomediastinum.  Heart size, mediastinal contour, and hila
#  are unremarkable. No evidence of radiopaque foreign body within the airway or
#  esophagus.
#
#  Visualized upper abdomen is unremarkable. Stable calcified left thyroid nodule
#  noted with thyroid goiter. Aortic arch calcifications noted.
# INDICATION: ___F with ?food impaction. Assess for visible foreign bodies, or
#  pneumomediastinum.
#
#
# s58487107
# FINDINGS: Stable calcified left thyroid nodule. No evidence of foreign bodies
#  along the airways or the esophagus.  Cardiomediastinal silhouette and hila are
#  normal.  There is no pleural effusion and no pneumothorax.  The lungs are
#  clear.
# INDICATION: ___-year-old woman with history of CVA; foreign body after
#  choking.
#
#
# s55836587
# FINDINGS: Cardiomediastinal contours are normal.  There are is stable bilateral
#  calcified granulomas, otherwise The lungs are clear.  Left lower lobe scarring
#  is unchanged.  There is no pneumothorax or pleural effusion.  The osseous
#  structures are unremarkable
# INDICATION: ___ year old woman with positive Quantiferon gold, pt originally
#  from ___, no symptoms  // any sign of latent or active tb?
#
#
# s59358936
# FINDINGS: Heart size is normal.  The aorta is tortuous.  The pulmonary vasculature and
#  hilar contours are normal.  Lungs are hyperinflated but clear. No focal
#  consolidation, pleural effusion or pneumothorax is present.  No acute osseous
#  abnormality is identified.
# INDICATION: ___M with subacute CVA seen on MRI
#
#
# s54385701
# FINDINGS: Unchanged heart size, mediastinal and hilar contours.  No focal consolidation,
#  pleural effusion or pneumothorax.  A 5 mm dense nodule in the left lower lung
#  is unchanged dating back to ___ compatible with a benign nodule.
# INDICATION: ___M with epigastric pain  // evaluate for pleural
#  effusion or pneumonia
#
#
# s52116555
# FINDINGS: AP portable upright view of the chest.   Interval resolution of right lower
#  lobe pneumonia.  No focal consolidation, large effusion or pneumothorax.  No
#  signs of congestion or edema.  Cardiomediastinal silhouette is normal.  Bony
#  structures are intact.
# INDICATION: ___M with low O2 sats  // eval for infiltrate, edema
#
#
# s56438849
# FINDINGS: There is a new right lower lobe infiltrate.  There small bilateral effusions
#  right greater than left
# INDICATION: ___ year old man with fever of 102  // Please r/o pneumonia vs.
#  atelectasis
#
#
# s52654671
# FINDINGS: Since the radiographs obtained ___, no significant changes are
#  appreciated. Lungs are fully expanded and clear without consolidations or
#  effusions. Heart size is normal. Cardiomediastinal and hilar silhouettes are
#  normal. Pleural surfaces are normal.
# INDICATION: ___ year old woman with increased seizure frequency // eval for
#  pna
#
#
# s53468612
# FINDINGS: PA and lateral views of the chest ___ at 09:55 are submitted.
# INDICATION: ___F smoker with recent seizures who has new cough and decreased
#  breath sounds at left base.  // eval for left lower lung infiltrate     eval
#  for left lower lung infiltrate
#
#
# s55928380
# FINDINGS: PA and lateral views of the chest provided. There is no focal consolidation,
#  effusion, or pneumothorax. The cardiomediastinal silhouette is normal.  No
#  acute fracture.  Deformity of the right distal clavicle again noted.  No free
#  air below the right hemidiaphragm is seen.
# INDICATION: ___F with seizure d/o p/w seizure
#
#
# s51540539
# FINDINGS: There are unchanged signs of marked overinflation.
#
#  Newly appeared are relatively extensive parenchymal opacities in the right
#  upper lobe and in the left upper lobe.  Additional opacities are seen at the
#  bases of the right upper lobe.
#
#  In the appropriate clinical context, the findings are consistent with
#  multifocal pneumonia.  At the time of observation and dictation, 11:41 a.m.,
#  on ___, the referring physician, ___. ___ was paged for notification
#  and the findings were subsequently discussed over the telephone.
#
#  No reactive pleural effusions.  No cardiomegaly, no hilar or mediastinal
#  changes.
# INDICATION: CHEST RADIOGRAPH
#
#
# s56852836
# FINDINGS: Marked hyperinflation and diaphragmatic flattening is unchanged.
#  There is no consolidation, pleural effusion or pneumothorax.  The
#  cardiomediastinal silhouette is normal.  There are no acute changes.
# INDICATION: Increased dyspnea.
#
#
# s57376136
# FINDINGS: The lungs are normally expanded and clear.  The cardiomediastinal silhouette,
#  hilar contours, and pleural surfaces are normal.  There is no pleural effusion
#  or pneumothorax.  There is a surgical screw in the right humeral head.
# INDICATION: ___F with weakness, altered mental status, c/f infection
#  // Evidence of acute process
#
#
# s58119794
# FINDINGS: Single AP upright view of the chest provided.   No free air seen below the
#  right hemidiaphragm. Tunneled screw is seen in the right humeral head. Dual
#  barrel Port-A-Cath tip extends to the low SVC. Lungs are grossly clear. No
#  pleural effusion or pneumothorax. Hilar and cardiomediastinal contours are
#  normal.
# INDICATION: ___F with abd pain, ?perf
#
#
# s59950007
# FINDINGS: AP upright and lateral views of the chest provided.  Port-A-Cath resides over
#  the right chest wall with catheter tip extending to the low SVC. The lungs
#  appear clear without focal consolidation, large effusion or pneumothorax. The
#  cardiomediastinal silhouette is stable. No convincing signs of edema or
#  pneumonia. Bony structures are intact.
# INDICATION: ___F with AMS, weakness, fatigue, Hx of GBM
#
#
# s55388853
# FINDINGS: The lungs are clear of focal consolidation, pleural effusion or pneumothorax.
#  The heart size is normal.  The mediastinal contours are normal.
# INDICATION: ___M with cp, bandlike  // eval pneumonia vs pneumothorax
#
#
# s55947854
# FINDINGS: The heart size is normal.  The hilar and mediastinal contours are
#  normal.  The lungs are well expanded and clear.  There is no pleural effusion
#  or pneumothorax. The visualized osseous structures are normal.
# INDICATION: ___-year-old male with five-day history of fever and productive
#  cough who presents for evaluation of pneumonia.
#
#
# s59391463
# FINDINGS: The patient is status post median sternotomy, and mitral and tricuspid valve
#  replacements with multiple mediastinal clips again noted.  Heart size is
#  normal.  Mediastinal and hilar contours are within normal limits.  Pulmonary
#  vasculature is normal.  Lungs are clear.  No pleural effusion or pneumothorax
#  is identified.  No acute osseous abnormalities are visualized.
# INDICATION: ___M with dyspnea on exertion
#
#
# s51613820
# FINDINGS: AP semi upright view of the chest provided.
#
#  There is no focal consolidation, effusion, or pneumothorax.  Bibasilar
#  atelectasis is similar to prior.  Mild cardiomegaly and large hiatal hernia
#  are similar to prior. Imaged osseous structures are intact.  No free air below
#  the right hemidiaphragm is seen.
# INDICATION: ___F with fall from standing. Reports headache, neck
#  pain, Tspine TTP, right shoulder TTP  // eval for ICH, spinal fracture,
#  shoulder fracture/fracture
#
#
# s58898689
# FINDINGS: AP and lateral views of the chest.  In the mid right lung, there is
#  a new round opacity that is concerning for a mass however may represent focal
#  infection.  There is no pleural effusion or pneumothorax.  No focal
#  consolidation.  Cardiomediastinal and hilar contours are normal.
# INDICATION: Breast cancer, on chemotherapy, evaluate for pneumonia.
#
#
# s52257272
# FINDINGS: The lungs are well expanded and clear.  There is no pleural effusion or
#  pneumothorax.  The cardiomediastinal silhouette is unremarkable.
# INDICATION: ___M with chest pain, pls eval for effusion vs ptx
#
#
# s52341872
# FINDINGS: PA and lateral views of the chest provided.  Lungs are clear.  No focal
#  consolidation, large effusion or pneumothorax.  Heart size is normal.
#  Mediastinal contour is stable. No acute osseous abnormality.
# INDICATION: ___M with several wks increasing anasarca, peripheral edema, hx of
#  CHF
#
#
# s56958909
# FINDINGS: PA and lateral views of the chest provided.
#
#  There is no focal consolidation, effusion, or pneumothorax. The
#  cardiomediastinal silhouette is normal. Imaged osseous structures are
#  unremarkable.  No free air below the right hemidiaphragm is seen.
# INDICATION: ___M with cough productive of brown sputum, mild dyspnea for 4
#  days  // Eval for PNA
#
#
# s50370759
# FINDINGS: Heart size is mildly enlarged, but the patient is rotated.  No pleural
#  effusions, pneumothorax, or focal consolidation concerning for pneumonia.
# INDICATION: ___F with leg swelling and sob.  Evaluate for heart failure.
#
#
# s57771640
# FINDINGS: The cardiomediastinal and hilar contours are normal. There is no pleural
#  effusion or pneumothorax. The lungs are well-expanded clear without focal
#  consolidation concerning for pneumonia.  The upper abdomen is unremarkable.
# INDICATION: ___F with asthma, HTN, HLD with presyncope, back pain, and
#  hypotension.  // r/o PNA, widened mediastinum
#
#
# s51611632
# FINDINGS: Interval improvement in the presumed post radiation paramediastinal
#  pneumonitis.  Interval improvement in the pulmonary edema.  The patient has
#  been extubated.  Transvenous right atrial and right ventricular pacer
#  defibrillator leads continuous from the left pectoral generator.  No
#  pneumothorax.  Bilateral pleural effusions noted.  Persistent adjacent lower
#  lobe atelectasis.  Indwelling pin in situ in the midshaft of the right
#  clavicle.
# INDICATION: ___ year old man with hx EF ___% s/p anaphylactic shock  //
#  interval change
#
#
# s50251498
# FINDINGS: Compared to the prior study there is no significant interval change.
# INDICATION: ___ year old man with chf exacerbation and flash pulm edema  // ?
#  volume overload
#
#
# s55529910
# FINDINGS: Compared to the prior study there is no significant interval change.
# INDICATION: ___ year old man with acute hypoxic respiratory failure  //
#  progression of b/l lung disease
#
#
# s55091394
# FINDINGS: A dual lead pacemaker is unchanged in position when compared to the prior
#  study.  A surgical pin transfixes the right clavicle.  There is moderate
#  cardiomegaly with a left ventricular enlargement pattern.  The right
#  peritracheal lymphadenopathy is difficult to evaluate on these radiographs,
#  there is no significant interval change in terms of the mediastinal contour
#  when compared to the prior study.  Lung volumes are within normal limits.  No
#  consolidation, pneumothorax or pleural effusion seen.
# INDICATION: ___ year old man with right lower paratracheal lymph node mass and
#  mediastinal/hilar lymphadenopathy  // Any change in mass size?
#
#
# s54877294
# FINDINGS: The tip of the endotracheal tube projects over the mid thoracic trachea.  A
#  gastric tube extends to the body of the stomach.  Pacing leads are again noted
#  overlying the right atrium and right ventricular apex with the battery pack
#  projecting over the left hemi abdomen.  Unchanged pacer leads along the left
#  lateral chest.
#
#  Slight interval decrease in the extent of the perihilar opacities.  A
#  persisting retrocardiac opacity is present, likely reflecting atelectasis and
#  a pleural effusion.  No pneumothorax identified.
#
#  Surgical clips project over the right upper quadrant.
# INDICATION: ___ year old man with acute respiratory failure  // ?interval
#  change
#
#
# s56813646
# FINDINGS: Endotracheal tube tip terminates approximately 5.4 cm from the carina.  An
#  enteric tube tip is within the stomach.  Abandoned pacing leads are noted
#  within the chest wall, some which terminate in the region the right atrium and
#  right ventricle.  Moderate cardiomegaly is present.  There is moderate
#  pulmonary edema with perihilar alveolar opacities.  Small left pleural
#  effusion is noted.  Bibasilar airspace opacities may reflect atelectasis, but
#  infection or aspiration is not excluded.  No large pneumothorax is detected.
#  No displaced fractures are evident.
# INDICATION: ___M status post arrest status post intubation, please assess lung
#  fields, tube placement
#
#
# s54916791
# FINDINGS: A bedside AP radiograph of the chest demonstrates new pulmonary
#  edema as well as engorgement of the mediastinal vasculature, consistent with
#  acute exacerbation of congestive heart failure.  In addition there may be
#  consolidation of the left lower lobe obscuring the descending aortic contour.
#  There is no pneumothorax or pleural effusion.  The heart size is top normal.
# INDICATION: Acute hypoxemia in patient on Remicade for psoriatic arthritis
#  with leukocytosis and concern for atypical pneumonia.
#
#
# s59148620
# FINDINGS: The lungs are clear of airspace or interstitial opacity.  The
#  cardiomediastinal silhouette is unremarkable.  No pleural effusions or
#  pneumothorax.  The patient has had prior surgery of the lower cervical and
#  upper lumbar spine with plate and screws incompletely visualized.
# INDICATION: ___ year old woman with cough, intermittent sob  // cough,
#  intermittent sob
#
#
# s56562065
# FINDINGS: PA and lateral radiographs of the chest demonstrate clear lungs.
#  The hilar and cardiomediastinal contours are normal.  There is no pneumothorax
#  or pleural effusion.  Pulmonary vascularity is normal.  Cervical fusion
#  hardware is incompletely imaged.
# INDICATION: Fever and cough in patient with psoriatic arthritis, on Remicade,
#  prednisone, and methotrexate.
#
#
# s56856304
# FINDINGS: Lung volumes are normal.  There is no focal consolidation, effusion, or
#  pneumothorax.  Small linear opacity in the right midlung laterally is
#  unchanged since ___.  Mediastinal and hilar contours are normal. Heart size
#  is normal.
# INDICATION: ___F with chest pain, cough  // PNA, cardiac r/o
#
#
# s57576246
# FINDINGS: Lung volumes are low.  No focal consolidation, pleural effusion, or
#  pneumothorax is detected on this view.  Heart size is top normal, which may be
#  exaggerated by low lung volumes and positioning.  Surgical clips project over
#  the right upper quadrant.
# INDICATION: ___-year-old female with altered mental status, hypoxic episode,
#  and fall.
#
#
# s51317108
# FINDINGS: Heart size is normal.  The mediastinal and hilar contours are normal. The
#  pulmonary vasculature is normal. Lungs are clear.  No pleural effusion or
#  pneumothorax is seen. There are no acute osseous abnormalities.  Remote
#  left-sided rib fractures are again demonstrated.
# INDICATION: ___M with chest pain
#
#
# s54114498
# FINDINGS: The left PICC ends in the mid-to-upper SVC.  Multiple healed
#  fractures are seen of the posterior ribs bilaterally, unchanged.  There is no
#  focal consolidation, pleural effusions or pneumothorax.  The cardiomediastinal
#  and hilar contours are normal.
# INDICATION: New PICC line.
#
#
# s51667140
# FINDINGS: The lungs are hyperinflated but clear without consolidation, effusion, or
#  edema.  Calcified granuloma identified at the left lung base.  Cardiac
#  silhouette is enlarged but not significantly changed given differences in
#  technique.  No acute osseous abnormalities, pectus deformity again noted.
# INDICATION: ___F with weakness  // PNA?
#
#
# s58106603
# FINDINGS: The lungs are clear without focal opacity, overt pulmonary edema, pleural
#  effusion or pneumothorax.  The cardiac and mediastinal contours are stable.
#  Old bilateral healed rib fractures are identified.
# INDICATION: ___M with chest pain, DOE x1 month, ESRD not on dialysis.
#
#
# s58569907
# FINDINGS: Cardiac silhouette size remains mildly enlarged.  Mediastinal and hilar
#  contours are unremarkable.  Pulmonary vasculature is normal.  Calcified
#  granulomas, the largest in the the left lower lobe, are unchanged.  Lungs are
#  otherwise clear without focal consolidation.  No pleural effusion or
#  pneumothorax is demonstrated.  Mild degenerative changes are seen in the
#  thoracic spine.  Pectus deformity is again demonstrated.
# INDICATION: ___F with chest pain
#
#
# s51097504
# FINDINGS: SUSPECT BACKGROUND HYPERINFLATION, AS CAN BE SEEN WITH COPD.  THE HEART IS NOT
#  ENLARGED.  THE CARDIOMEDIASTINAL SILHOUETTE IS WITHIN NORMAL LIMITS.  NO CHF,
#  FOCAL INFILTRATE, OR EFFUSION IS IDENTIFIED.  NO PNEUMOTHORAX IS DETECTED.  A
#  THIN CURVILINEAR DENSITY EXTENDING VERTICALLY AT THE LEFT LUNG BASE COULD
#  REPRESENT SCARRING OR LESS LIKELY, THE EDGE OF A BULLA -- THIS IS UNCHANGED
#  COMPARED ___.
#
#  THERE IS MILD ANTERIOR WEDGING OF ___ MIDTHORACIC VERTEBRAL BODIES THAT IS
#  UNCHANGED COMPARED WITH ___.  .
# INDICATION: ___M with L sided cp  // eval for ptx, pna
#
#
# s54631659
# FINDINGS: Lungs are low in volume but clear.  There is no pleural effusion or
#  pneumothorax.  The heart is normal in size.  Normal cardiomediastinal
#  silhouette.  No displaced rib fractures are identified.
# INDICATION: Trauma to the chest, assess for cardiopulmonary abnormalities.
#
#
# s52605302
# FINDINGS: Frontal and lateral chest radiographs demonstrate hyperexpansion
#  but no focal consolidation, pleural effusion, or pneumothorax.  Additionally,
#  there is probably a component of emphysema in the lower lobes.  The hila are
#  elevated, suggesting scarring.  Pleuroparenchymal scarring is noted in the
#  apices.  The cardiomediastinal silhouette is normal.
# INDICATION: History of asthma and worsening shortness of breath.
#
#
# s58619815
# FINDINGS: The heart is normal in size.  The mediastinal and hilar contours appear within
#  normal limits.  The aortic arch shows patchy calcification.  Mild subpleural
#  thickening is unchanged at each lung apex for the most part, but there is an
#  apparent increase in density in the left upper lung over about 1 cm region.
#  Otherwise, the lung fields appear clear.  There are no pleural effusions or
#  pneumothorax.
# INDICATION: Palpitations and chest pressure.
#
#
# s57132437
# FINDINGS: The lungs are clear, and the cardiomediastinal silhouette and hila
#  are normal.  There is no pleural effusion and no pneumothorax.
# INDICATION: ___-year-old with chest pain.
#
#
# s59102406
# FINDINGS: PA and lateral views of the chest provided.
#
#  There is no focal consolidation, effusion, or pneumothorax. The
#  cardiomediastinal silhouette is normal. Imaged osseous structures are intact.
#  No free air below the right hemidiaphragm is seen.
# INDICATION: ___M with probable neutropenia and fever
#
#
# s58971208
# FINDINGS: The ET tube terminates approximately 2.9 cm from the carina.  The
#  NG tube courses below the diaphragm with the tip out of the field of view of
#  the film.  There has been interval worsening of the right linear opacification
#  likely secondary to atelectasis. No pneumothorax or definite pleural effusion
#  is seen. The hilar and mediastinal contours are normal. There is mild
#  cardiomegaly, stable compared to the preior exam.
# INDICATION: ___-year-old female intubated for head bleed, who presents for
#  evaluation of pneumonia.

# %%
# !pip install pydicom
# Out:
# Collecting pydicom
#   Downloading pydicom-3.0.1-py3-none-any.whl.metadata (9.4 kB)
# Downloading pydicom-3.0.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 26.9 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-3.0.1

# %%
len(glob('/content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR-filtered/*'))
# Out:
# 58

# %%
import json
from glob import glob
import os
import shutil
save_root = '/content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR-filtered/'
cases = glob('/content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR-processed/*')
case_ids = os.listdir('/content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR-processed/')
cnt = 0
for i, case in enumerate(cases):
  report_path = os.path.join(case, case_ids[i] + '.json')
  with open(report_path, 'r') as json_file:
    report = json.load(json_file)
  if 'INDICATION' in report.keys() and 'FINDINGS' in report.keys() and 'IMPRESSION' in report.keys():
    shutil.copytree(case, os.path.join(save_root, case_ids[i]))
    cnt += 1
print(cnt)
# Out:
# 58

# %%
import json
import re

def txt_to_dict(filename):
  with open(filename, 'r') as file:
      text = file.read()
  record = {}
  text_orig = text.replace("FINAL REPORT", "").strip()
  text = text_orig.split('\n \n')
  # print(text)
  track = 0
  if 'EXAMINATION' in text_orig:
    record['EXAMINATION'] = text[track].split(':')[-1].strip()
    track += 1
  if 'INDICATION' in text_orig:
    record['INDICATION'] = text[track].split(':')[-1].strip()
    track += 1
  if 'TECHNIQUE' in text_orig:
    record['TECHNIQUE'] = text[track].split(':')[-1].strip()
    track += 1
  if 'COMPARISON' in text_orig:
    record['COMPARISON'] = text[track].split(':')[-1].strip()
    track += 1
  if 'FINDINGS' in text_orig:
    record['FINDINGS'] = text_orig.split('FINDINGS:')[-1].strip().split('IMPRESSION:')[0].strip()
    # track += 1
    # record['FINDINGS'] = text[track].strip()
    # track += 1
  if 'IMPRESSION' in text_orig:
    record['IMPRESSION'] = text_orig.split('IMPRESSION:')[-1].strip()
    # track += 1
    # record['IMPRESSION'] = text[track].strip()
    # track += 1
  return record

filename = '/content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p10000032/s50414267.txt'
txt_to_dict(filename)
# Out:
# {'EXAMINATION': 'CHEST (PA AND LAT)',
#  'INDICATION': '___F with new onset ascites  // eval for infection',
#  'TECHNIQUE': 'Chest PA and lateral',
#  'COMPARISON': 'None.',
#  'FINDINGS': 'There is no focal consolidation, pleural effusion or pneumothorax.  Bilateral\n nodular opacities that most likely represent nipple shadows. The\n cardiomediastinal silhouette is normal.  Clips project over the left lung,\n potentially within the breast. The imaged upper abdomen is unremarkable.\n Chronic deformity of the posterior left sixth and seventh ribs are noted.',
#  'IMPRESSION': 'No acute cardiopulmonary process.'}

# %%
import os
import pydicom
from glob import glob
import cv2
import json
import numpy as np
import cv2
import shutil
root = '/content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/'
save_root = '/content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR-processed/'
os.makedirs(save_root, exist_ok=True)

patients = glob(os.path.join(root, 'p*'))
for patient in patients:
  scans = []
  for f in os.listdir(patient):
    if os.path.isdir(os.path.join(patient, f)):
      scans.append(f)
  for scan in scans:
    # scan_dict = {'imgs': [], 'report': []}
    scan_save_path = os.path.join(save_root, scan)
    os.makedirs(scan_save_path, exist_ok=True)
    imgs_path = os.path.join(save_root, scan, 'imgs')
    os.makedirs(imgs_path, exist_ok=True)

    report_json_path = os.path.join(scan_save_path, scan + '.json')
    print(os.path.join(patient, scan + '.txt'))
    report_dict = txt_to_dict(os.path.join(patient, scan + '.txt'))
    with open(report_json_path, 'w') as json_file:
      json.dump(report_dict, json_file, indent=4)

    scan_path = os.path.join(patient, scan)
    dcms = glob(os.path.join(scan_path, '*.dcm'))
    for dcm in dcms:
      img = pydicom.dcmread(dcm).pixel_array
      img = (img - img.min()) / (img.max() - img.min())
      img = (img * 255).astype(np.uint8)
      H, W = img.shape
      img = cv2.resize(img, (int(W / 4), int(H / 4)))
      cv2.imwrite(os.path.join(imgs_path, os.path.basename(dcm)[:-4] + '.png'), img)
# Out:
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p10000032/s50414267.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p10000032/s53189527.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p10000032/s53911762.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p10000032/s56699142.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p10000764/s57375967.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p11000011/s51029426.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p11000183/s50336039.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p11000183/s51967845.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p11000183/s53970869.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p11000183/s54898709.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p11000183/s57084339.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p11000183/s58117097.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p11000183/s58509443.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p11000183/s58555910.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p11000183/s58733084.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p11000183/s59289932.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p12000091/s55199984.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p12000091/s58487107.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p12000146/s52988409.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p12000146/s55836587.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p13000142/s55037150.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p13000759/s59358936.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p14000003/s51658914.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p14000340/s51800155.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000170/s54385701.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000170/s56450978.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000170/s57532252.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000393/s51634677.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000393/s52116555.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000393/s52929930.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000393/s53701643.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000393/s54674484.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000393/s54952309.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000393/s55479181.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000393/s55723653.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000393/s55843146.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000393/s56438849.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000393/s57099953.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000393/s58990129.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000393/s59128455.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15000393/s59788459.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p16000035/s52654671.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p16000035/s53468612.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p16000035/s55928380.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p16000210/s56889911.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p16000210/s57473175.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p16000210/s59788119.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s50595061.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s50666068.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s50708980.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s51441486.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s51540539.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s52381151.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s53160990.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s53655170.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s53838716.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s55918174.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s56722858.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s56826212.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s56852836.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s57002795.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s57092098.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s57283433.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s57516335.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s57771204.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s58657775.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s58663966.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s58803000.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s58960060.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s59015628.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000103/s59571256.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000354/s51755743.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000354/s57376136.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000354/s58119794.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17000354/s59950007.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p18000291/s55388853.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p18000379/s51062789.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p18000379/s51568340.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p18000379/s51817182.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p18000379/s53632378.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p18000379/s55748408.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p18000379/s55947854.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p18000379/s56020891.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p18000379/s57516501.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p18000379/s57979934.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p18000379/s58920421.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p18000379/s59261316.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p18000379/s59391463.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p19000065/s51613820.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p19000108/s58898689.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p10999512/s52257272.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p10999737/s52341872.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p10999737/s56958909.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p11999903/s57771640.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p11999982/s50370759.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p12999492/s56868461.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p12999691/s50251498.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p12999691/s50371912.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p12999691/s51611632.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p12999691/s53235694.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p12999691/s54000428.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p12999691/s54771382.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p12999691/s54877294.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p12999691/s55091394.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p12999691/s55529910.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p12999691/s55707622.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p12999691/s56813646.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p13999982/s53174726.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p13999982/s54916791.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p13999982/s56562065.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p13999982/s59148620.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p13999983/s56856304.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p13999983/s59289324.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p14999290/s53077596.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p14999290/s57576246.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p14999347/s54511370.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15999575/s51317108.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15999575/s54114498.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15999575/s55622492.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15999575/s56549379.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15999575/s58106603.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15999702/s51667140.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p15999702/s58569907.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p16999265/s57515204.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p16999540/s51097504.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p16999540/s52605302.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17999882/s54631659.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17999946/s55035390.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p17999946/s58619815.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p18999819/s59102406.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p18999837/s57392449.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p19999733/s57132437.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p19999987/s55368167.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p19999987/s58621812.txt
# /content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR/p19999987/s58971208.txt

# %%
len(os.listdir('/content/drive/MyDrive/Graduate/CS263_NLP/FinalProj/MIMIC-CXR-processed/'))
# Out:
# 90

# %%
script_content = """
for i in {10..19}; do
    # Get the list of the first two folders within each pXX directory
    folder_names=$(wget -q -O - "https://physionet.org/files/mimic-cxr/2.0.0/files/p$i/" | \
    grep -oP 'href="p\d+/"' | \
    sed 's/href="//;s|/||' | \
    tail -n 2)

    # Loop over the first two folders and download their contents
    for folder in $folder_names; do
        # Clean up the folder name by removing %22, trailing quotes, and spaces
        clean_folder=$(echo "$folder" | sed 's/%22//g' | sed 's/"$//g' | tr -d '[:space:]')

        # Print the cleaned folder name and URL to check it
        echo "Processing folder: $clean_folder"
        echo "URL: https://physionet.org/files/mimic-cxr/2.0.0/files/p$i/$clean_folder/"

        # Use wget to download the folder
        wget -r -N -c -np -nH --cut-dirs=5 "https://physionet.org/files/mimic-cxr/2.0.0/files/p$i/$clean_folder/"
    done
done
"""

# Write the script content to a file named "download_folders.sh"
with open("download_folders.sh", "w") as file:
    file.write(script_content)

# %%
# !chmod +x download_folders.sh
# !./download_folders.sh
